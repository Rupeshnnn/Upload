# %%
# import required libraries for this section
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# load in color image for face detection
image = cv2.imread('/home/rupesh/Pictures/RM.jpg')

# convert to RBG
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(20,10))
plt.imshow(image)

# %%
# convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  

plt.figure(figsize=(20,10))
plt.imshow(gray, cmap='gray')

# %%
# load in cascade classifier
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
# run the detector on the grayscale image
faces = face_cascade.detectMultiScale(gray, 1, 5)
eyes = eye_cascade.detectMultiScale(gray, 2, 3)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-89e736d84ae8> in <module>
#       3 eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
#       4 # run the detector on the grayscale image
# ----> 5 faces = face_cascade.detectMultiScale(gray, 1, 5)
#       6 eyes = eye_cascade.detectMultiScale(gray, 2, 3)
#
# error: OpenCV(4.2.0) /io/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

# %%
img_with_detections = np.copy(image)   # make a copy of the original image to plot rectangle detections ontop of

# loop over our detections and draw their corresponding boxes on top of our original image
for (x,y,w,h) in faces:
    # draw next detection as a red rectangle on top of the original image.  
    # Note: the fourth element (255,0,0) determines the color of the rectangle, 
    # and the final argument (here set to 5) determines the width of the drawn rectangle
    for (x,y,w,h) in eyes:
        cv2.rectangle(img_with_detections,(x,y),(x+w,y+h+60),(255,34,34),5)
    cv2.rectangle(img_with_detections,(x,y),(x+w,y+h),(255,34,34),5)  
# print(x,y)
# print(w,h)
# print(x+w,y+h)
# display the result
plt.figure(figsize=(20,10))
plt.imshow(img_with_detections)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d962d5a697d6> in <module>
#       2
#       3 # loop over our detections and draw their corresponding boxes on top of our original image
# ----> 4 for (x,y,w,h) in faces:
#       5     # draw next detection as a red rectangle on top of the original image.
#       6     # Note: the fourth element (255,0,0) determines the color of the rectangle,
#
# NameError: name 'faces' is not defined
