# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('sun.jpg',0)
# taking kernel and normalized
kernel = np.ones([3,3],dtype = np.float32)/9

blured_img = cv2.filter2D(img,-1,kernel)
plt.imshow(blured_img)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('sun.jpg',0)
# taking kernel and normalized
kernel = np.array([[1,-2,3],[-1,2,1],[3,2,2]])/11

blured_img = cv2.filter2D(img,-1,kernel)
# plt.imshow(blured_img)
blured_img
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('209px-Flag_of_Nepal.svg.png',0)
# taking kernel and normalized
kernel = np.array([[1,-2,3],[-1,2,1],[3,2,1]])/10

blured_img = cv2.filter2D(img,-1,kernel)
plt.imshow(blured_img)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('sun.jpg',0)
# taking kernel and normalized
kernel = np.zeros([3,3],dtype = np.float32)/0

blured_img = cv2.filter2D(img,-1,kernel)
plt.imshow(blured_img)
# Out:
# C:\Users\coral\Anaconda3\envs\the_best_chatbot\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('209px-Flag_of_Nepal.svg.png')
# Converting BGR to RGB
image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# Converting RGB to gray
gray = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
# taking kernel and normalized
kernel = np.array([[1,-2,3],[-1,2,1],[3,2,1]])/10

blured_img = cv2.filter2D(gray,-1,kernel)
plt.imshow(blured_img)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('209px-Flag_of_Nepal.svg.png')
# Converting BGR to RGB
image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# Converting RGB to gray
gray = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
# taking kernel and normalized
kernel = np.array([[1,-2,3],[-1,2,1],[3,2,1]])/10

blured_img = cv2.filter2D(gray,-1,kernel)
plt.imshow(blured_img,cmap = 'gray')

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('sun.jpg')
# Converting BGR to RGB
image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# Converting RGB to gray
gray = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
# taking kernel and normalized
kernel = np.array([[-1,-2,-1], 
                   [ 0, 0, 0], 
                   [ 1, 2, 1]])

blured_img = cv2.filter2D(gray,-1,kernel)
plt.imshow(blured_img,cmap = 'gray')

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('sun.jpg')
height,width = img.shape[:2]
start_row,start_col = int(height*0.25),int(width*0.25)
end_row,end_col = int(height*0.75),int(width*0.75)
# croppwd_image = img[start_row:end_row,start_col:end_col]
croppwd_image = img[start_row:end_row,start_col:end_col]
cv2.imshow("Original Image",img)
cv2.waitKey(0)
cv2.imshow("Cropped Image",croppwd_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
